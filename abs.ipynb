# %%
import pandas as pd
import glob

# %%
# choose the columns you want to extract
cols = [
    "contig", "gene_id", "position",
    "A_frequency_p_value_tTest_abs", "A_frequency_p_value_MannWhitney_abs",
    "T_frequency_p_value_tTest_abs", "T_frequency_p_value_MannWhitney_abs",
    "G_frequency_p_value_tTest_abs", "G_frequency_p_value_MannWhitney_abs",
    "C_frequency_p_value_tTest_abs", "C_frequency_p_value_MannWhitney_abs",
    "num_samples_UC", "num_samples_control","notes"
]

# find all *.tsv.gz files
files = glob.glob("two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/*.tsv.gz")

subset_files = []

for f in files:
    print("Reading:", f)
    df = pd.read_csv(f, sep="\t", compression="gzip")
    df_subset = df[cols]

    out = f.replace(".tsv.gz", "_subset.tsv.gz")
    df_subset.to_csv(out, sep="\t", compression="gzip", index=False)
    subset_files.append(out)

    print("Wrote:", out)

# --- concatenate all subset files ---
print("\nConcatenating all subset files...")

dfs = [pd.read_csv(f, sep="\t", compression="gzip") for f in subset_files]
merged = pd.concat(dfs, ignore_index=True)

merged.to_csv("all_subsets_merged_ct_0.1.tsv.gz", sep="\t", compression="gzip", index=False)
# Out:
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000002545_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000002545_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000002549_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000002549_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000004769_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000004769_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000000029_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000000029_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000001378_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000001378_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000002619_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000002619_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000001346_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000001346_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000000022_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000000022_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000000196_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000000196_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000002223_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000002223_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000002438_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000002438_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000002670_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000002670_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000003681_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000003681_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000002492_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000002492_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000002272_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000002272_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000002327_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000002327_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000000271_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000000271_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000000099_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000000099_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000002478_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000002478_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000000057_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000000057_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000000074_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000000074_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000001345_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000001345_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000002528_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000002528_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000000044_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000000044_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000001294_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000001294_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000000512_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000000512_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000000013_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000000013_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000002040_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000002040_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000002641_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000002641_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000000076_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000000076_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000004679_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000004679_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000000060_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000000060_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000000876_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000000876_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000003166_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000003166_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000000251_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000000251_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000003937_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000003937_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000003899_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000003899_two_sample_unpaired_subset.tsv.gz
# Reading: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000004797_two_sample_unpaired.tsv.gz
# Wrote: two_sample_unpaired_initial_second-UC_control_coverage_threshold_0.1/MGYG000004797_two_sample_unpaired_subset.tsv.gz
#
# Concatenating all subset files...
# /var/folders/0g/jffzlx7x0v37frp3q4ssdnp80000gn/T/ipykernel_91859/1111328907.py:31: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   merged = pd.concat(dfs, ignore_index=True)

# %%
from statsmodels.stats.multitest import multipletests
import pandas as pd

df = pd.read_csv("all_subsets_merged_ct_0.1.tsv.gz", sep="\t", compression="gzip")

pvals = df[
    [
        "A_frequency_p_value_tTest_abs",
        "A_frequency_p_value_MannWhitney_abs",
        "T_frequency_p_value_tTest_abs",
        "T_frequency_p_value_MannWhitney_abs",
        "G_frequency_p_value_tTest_abs",
        "G_frequency_p_value_MannWhitney_abs",
        "C_frequency_p_value_tTest_abs",
        "C_frequency_p_value_MannWhitney_abs"
    ]
]
    
corrected = pvals.apply(lambda col: multipletests(col, method='fdr_bh')[1])


corrected.columns = [c + "_FDR" for c in corrected.columns]
df_corrected = pd.concat([df, corrected], axis=1)

df_corrected.to_csv("all_subsets_with_FDR_ct_0.1.tsv.gz", sep="\t", compression="gzip", index=False)

# %%
df_corrected.to_csv("all_subsets_with_FDR_ct_0.1.tsv", sep="\t", index=False)

# %%
df_corrected['T_frequency_p_value_MannWhitney_abs_FDR'].min()
# Out:
# 1.0
